# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
X, y = fetch_openml('mnist_784', return_X_y=True)

# %%
# assuring mean = 0, standard deviation = 1
stand_mnist = StandardScaler().fit_transform(X)
print(stand_mnist.shape)
#covariance matrix
covar_matrix = np.matmul(stand_mnist.T , stand_mnist)
print(covar_matrix.shape)
# Out:
# (70000, 784)
# (784, 784)

# %%
colors_d = {'0': 'red','1': 'blue','2':'green','3': 'orange','4': 'fuchsia','5':'pink','6':'brown','7':'dimgray','8':'aqua','9':'lime'}
colors = [colors_d[i] for i in y]

# %%
n_components = 2
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111)
ax.scatter(X_pca[:, 0], X_pca[:, 1], c=colors)
ax.set_xlabel('Principal component 1')
ax.set_ylabel('Principal component 2')
plt.show()
